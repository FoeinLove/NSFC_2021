# %%
import pandas as pd

# %%
d1 = pd.read_stata('Sample_Infor.dta')

# %%
d1.head()
# Out:
#              ID householdID communityID longitudinal     died iyear imonth  \
# 0  010104101001  0101041010     0101041        1 Yes  0 Alive  2014     07
# 1  010104101002  0101041010     0101041        1 Yes  0 Alive  2014     07
# 2  010104102001  0101041020     0101041        1 Yes  0 Alive  2014     07
# 3  010104102002  0101041020     0101041        1 Yes  0 Alive  2014     07
# 4  010104103001  0101041030     0101041        1 Yes  0 Alive  2014     07
#
#   versionID
# 0  20160601
# 1  20160601
# 2  20160601
# 3  20160601
# 4  20160601

# %%
d2 = pd.read_stata('Work_History.dta')

# %%
d2.head()
# Out:
#              ID householdID communityID    f_1 f_1_0 f_1_1 f_1_2  f001s1  \
# 0  010104101001  0101041010     0101041  1 Yes   NaN   NaN   NaN     NaN
# 1  010104101002  0101041010     0101041  1 Yes   NaN   NaN   NaN     NaN
# 2  010104102001  0101041020     0101041  1 Yes   NaN   NaN   NaN  1 Work
# 3  010104102002  0101041020     0101041  1 Yes   NaN   NaN   NaN  1 Work
# 4  010104103001  0101041030     0101041  1 Yes   NaN   NaN   NaN     NaN
#
#   f001s2 f001s3  ... f131_1 f131_2 f131_3 f131_4  f150 f151 f152_1 f152_2  \
# 0    NaN    NaN  ...    NaN    NaN    NaN    NaN  2 No  NaN    NaN    NaN
# 1    NaN    NaN  ...    NaN    NaN    NaN    NaN  2 No  NaN    NaN    NaN
# 2    NaN    NaN  ...    NaN    NaN    NaN    NaN  2 No  NaN    NaN    NaN
# 3    NaN    NaN  ...    NaN    NaN    NaN    NaN  2 No  NaN    NaN    NaN
# 4    NaN    NaN  ...    NaN    NaN    NaN    NaN  2 No  NaN    NaN    NaN
#
#   f153 versionID
# 0  NaN  20160601
# 1  NaN  20160601
# 2  NaN  20160601
# ...

# %%
 2024  -4
# Out:
# 2020
